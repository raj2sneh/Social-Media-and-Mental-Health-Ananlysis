# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/smmh.csv")
df
# Out:
#               Timestamp  1. What is your age? 2. Gender  \
# 0    4/18/2022 19:18:47                  21.0      Male
# 1    4/18/2022 19:19:28                  21.0    Female
# 2    4/18/2022 19:25:59                  21.0    Female
# 3    4/18/2022 19:29:43                  21.0    Female
# 4    4/18/2022 19:33:31                  21.0    Female
# ..                  ...                   ...       ...
# 476  5/21/2022 23:38:28                  24.0      Male
# 477   5/22/2022 0:01:05                  26.0    Female
# 478  5/22/2022 10:29:21                  29.0    Female
# 479  7/14/2022 19:33:47                  21.0      Male
# 480    11-12-2022 13:16                  53.0      Male
#
#     3. Relationship Status 4. Occupation Status  \
# 0        In a relationship   University Student
# 1                   Single   University Student
# 2                   Single   University Student
# 3                   Single   University Student
# ...

# %%
# Check whether there exist duplicates or not
print(df.duplicated().sum())
# Out:
# 0

# %%
# Drop some unncecessary columns

df = df.drop(['Timestamp','5. What type of organizations are you affiliated with?','12. On a scale of 1 to 5, how easily distracted are you?','13. On a scale of 1 to 5, how much are you bothered by worries?'], axis = 1)
print(df)
# Out:
#      1. What is your age? 2. Gender 3. Relationship Status  \
# 0                    21.0      Male      In a relationship
# 1                    21.0    Female                 Single
# 2                    21.0    Female                 Single
# 3                    21.0    Female                 Single
# 4                    21.0    Female                 Single
# ..                    ...       ...                    ...
# 476                  24.0      Male                 Single
# 477                  26.0    Female                Married
# 478                  29.0    Female                Married
# 479                  21.0      Male                 Single
# 480                  53.0      Male                Married
#
#     4. Occupation Status 6. Do you use social media?  \
# 0     University Student                         Yes
# 1     University Student                         Yes
# 2     University Student                         Yes
# ...

# %%
# Check whether Null values exists or not

print(df.isnull().sum())
# Out:
# 1. What is your age?                                                                                                    0
# 2. Gender                                                                                                               0
# 3. Relationship Status                                                                                                  0
# 4. Occupation Status                                                                                                    0
# 6. Do you use social media?                                                                                             0
# 7. What social media platforms do you commonly use?                                                                     0
# 8. What is the average time you spend on social media every day?                                                        0
# 9. How often do you find yourself using Social media without a specific purpose?                                        0
# ...

# %% [markdown]
# So, till here our Data is clean and sorted.

# %%
df.to_csv('smmh_cleaned.csv', index = False)

from google.colab import files
files.download('smmh_cleaned.csv')
